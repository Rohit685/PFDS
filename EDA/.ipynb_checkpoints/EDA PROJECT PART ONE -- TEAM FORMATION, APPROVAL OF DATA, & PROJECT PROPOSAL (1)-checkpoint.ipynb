# %% [markdown]
# # <center>EDA Project Part One</center>
# # <center>Team Formation, Selection & Approval of Data, and Project Proposal</center>

# %% [markdown]
# <div class="alert alert-block alert-info">The EDA project in this course has six main parts to it: <br>
#
# 1. Team Formation, Approval of Data, and Project Proposal
# 2. EDA Practice and Trial Run(Optional)
# 3. Phase 1 (Data Cleaning / Data Wrangling)
# 4. Phase 2 (Data Analysis)
# 5. Report
# 6. Conferences with Instructor (You will be required to have 5 conferences -- one for each of the first 5 parts.)
#
# - The first four parts will be completed in Jupyter Notebooks and delivered both as a .ipynb file and as an HTML file or PDF.
# - Note: Part 2 will be optional.
#
# ***
#
# - The Part 5 report will be completed outside of Jupyter Notebook and will delivered as a PDF.
#
# Detailed instructions for each phase will be provided.</div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b><font size=4>Read this before proceeding:</font></b>
#
#  It is expected that when you are asked questions requiring typed explanations you are to use a <b><u>markdown cell</u></b> to type your answers neatly. <b><u><i>Do not provide typed answers to questions as extra comments within your code.</i></u></b> Only provide comments within your code as you normally would, i.e. as needed to explain or remind yourself what each part of the code is doing.</div>

# %% [markdown]
# The Project Proposal part of this assignment consists of selecting data and answering a few questions related to your data.
#
# Before choosing your data, there are some guidelines to consider:
#
# 1. The datset that you choose must be approved by me.
# 2. It is best if your data comes from an original source.
# 3. Focus on choosing data for which there is no readily available analysis found online.
# 4. It’s best to choose data based on a topic that interests you or that falls within your area(s) of expertise.
# 5. If you are struggling to find data, let me know.
#
# Once you’ve chosen your data and have completed the Project Proposal tasks in the notebook, submit your completed notebook and data file(s), and html/pdf file for grading.
#
# ### To prepare you further for this project consider exploring the resources provided below:
#
# **Outline of Steps**
#
# [**EDA Outline & Tutorial**](file:///C:/Users/ritte/OneDrive/Documents/PFDS/EDA%20Outline%20of%20Steps.pdf)
#
# **Articles**
#
# 1. [**A Guide to EDA in Python**](https://drive.google.com/file/d/1hU3W__7i6C3GFFve5DnODDsQmyccliyq/view?usp=sharing)
# 2. [**Exploratory Data Analysis in Python**](https://towardsdatascience.com/exploratory-data-analysis-in-python-c9a77dfa39ce)
# 3. [**Exploratory DataAnalysis (EDA) in Python**](https://medium.com/@atanudan/exploratory-data-analysis-eda-in-python-893f963cc0c0)
# 4. [**Exploratory Data Analysis (EDA) in Python!**](https://www.analyticsvidhya.com/blog/2020/08/exploratory-data-analysiseda-from-scratch-in-python/)
# 5. [**How to Perform Exploratory Data Analysis -- A Guide for Beginners**](https://www.analyticsvidhya.com/blog/2021/08/how-to-perform-exploratory-data-analysis-a-guide-for-beginners/)
# 6. [**Exploratory Data Analysis with Some Cool Visualizations in Python’s Matplotlib and Seaborn Library**](https://towardsdatascience.com/exploratory-data-analysis-with-some-cool-visualizations-in-pythons-matplotlib-and-seaborn-library-99dde20d98bf)
# 7. [**The Data Science Method**](https://aiden-dataminer.medium.com/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9)
#
#
# **Video**
#
# [**Exploratory Data Analysis in Python (Simplilearn)**](https://www.youtube.com/watch?v=MoM6mighOJM)
#
#
# **Cheat Sheets**
#
# - [**Importing Data**](https://drive.google.com/file/d/1TlvsH0VQMfwlAnqyHu4cAs6AE30V97nf/view?usp=sharing)
# - [**Matplotlib**](https://drive.google.com/file/d/1YCV7gP49EzfKzO_nvQA8i7vSC9AFso_t/view?usp=sharing)
# - [**NumPy**](https://drive.google.com/file/d/1ylyxXc5eIMTUchp7dUTb0N-QrDZQgymr/view?usp=sharing)
# - [**Pandas Basics**](https://drive.google.com/file/d/1WkJJ6qVLYK9AoOE7RqHesPBgyRzGSc5D/view?usp=sharing)
# - [**Pandas**](https://drive.google.com/file/d/1yo9zcJYkpnS5RgM5ZCOEPmBACM7WR4q9/view?usp=sharing)
# - [**Python Basics**](https://drive.google.com/file/d/1bGrS3qaihvu7d02t-3X88kaRNk18elq6/view?usp=sharing)
# - [**Seaborn**](https://drive.google.com/file/d/1blXzF795Ixk8Ar3wYhkNCYDS0XD1mLqT/view?usp=sharing)
# - [**EDA in Python**](https://www.analyticsvidhya.com/blog/2015/06/infographic-cheat-sheet-data-exploration-python/)

# %% [markdown]
# ## What is Exploratory Data Analysis (EDA)?
#
# Exploratory Data Analysis (EDA) is used on the one hand to answer questions, test business assumptions, generate hypotheses for further analysis. On the other hand, you can also use it to prepare the data for modeling. The thing that these two probably have in common is a good knowledge of your data to either get the answers that you need or to develop an intuition for interpreting the results of future modeling.
#
# There are a lot of ways to reach these goals: you can get a basic description of the data, visualize it, identify patterns in it, identify challenges of using the data, etc.
#
# One of the things that you’ll often see when you’re reading about EDA is Data profiling. Data profiling is concerned with summarizing your dataset through descriptive statistics. You want to use a variety of measurements to better understand your dataset. The goal of data profiling is to have a solid understanding of your data so you can afterwards start querying and visualizing your data in various ways. However, this doesn’t mean that you don’t have to iterate: exactly because data profiling is concerned with summarizing your dataset, it is frequently used to assess the data quality. Depending on the result of the data profiling, you might decide to correct, discard or handle your data differently.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Project Proposal

# %% [markdown]
# <div class="alert alert-block alert-info">The intent of this assignment is for you to form your team, select your data, and share your chosen data file(s) with your instructor and provide general information on your goals for the EDA project.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 1 (5 pts)</b>: List the members of your team.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 2 (25 pts)</b>: Check with your instructor to see if your data will be approved. Your instructor will fill in the cell below to indicate if your data has been approved.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 3 (10 pts)</b>: Give a brief <i><u>description</u></i> of the source(s) of your data and include a <i><u>direct link</u></i> to your data.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 4 (5 pts)</b>: Briefly explain why you chose this data.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 5 (10 pts)</b>: Provide a brief overview of your goals for this project.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 6 (30 pt)</b>: List 10 questions that you could ask about your dataset. These questions should serve as starting points and guides to your investigation..</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 7 (30 pt)</b>: Formulate at least 3 hypotheses related to your data. Along with the questions in Step 4 above, these hypotheses should also serve as starting points and guides to your investigation.   </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 8 (10 pt)</b>: Read the data into this notebook.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Step 9 (15 pts)</b>: Inspect your dataset using appropriate methods and attributes.  Consider using the following options:
#
# - <b>info(&nbsp;)</b> method
# - <b>head(&nbsp;)</b> method
# - <b>tail(&nbsp;)</b> method
# - <b>index(&nbsp;)</b> attribute
# - <b>columns(&nbsp;)</b> attribute
# - <b>shape(&nbsp;)</b> attribute
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"><b>STOP HERE for your Project Proposal assignment. Submit your (1) original data file(s) along with (2) the completed notebook up to this point, and (3) the html/pdf file for grading and approval.</b></div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Instructor Feedback and Approval (10 pts)</b>: Your instructor will provide feedback in either the cell below this or via Google Classroom. You can expect one of the following point values for this portion.
#
# <b>10 pts</b> - if your project goals and data set are both approved.<br>
# <b>8 pts</b> - if your data set is approved but changes to your project goals (Step 3) are needed.<br>
# <b>5 pt</b> - if your project goals are approved but your data set is not approved.<br>
# <b>0 pts</b> - if neither your data set nor your project goals are approved.<br><br>
#
# <i><u>As needed, follow your instructor's feeback and guidance to get on track for the remaining portions of the EDA project.</u></i>
# </div>
