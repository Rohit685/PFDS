# %% [markdown]
# # <center><b>Asg 19.1 Pandas Series (Coding)</b></center>
# ![6.jpg](attachment:6.jpg)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="4">Files needed for this assignment:</font></b>
# </div>

# %% [markdown]
# [schools](https://drive.google.com/file/d/1SC-WEXCPDHofUOvkP9_2Oi3MrHQJaJa2/view?usp=share_link)<br>
# [fortune1000](https://drive.google.com/file/d/1lUyWNvgNFK4TWgpBysAc3fJQvsGAxFpl/view?usp=share_link)

# %%
# set up notebook to display multiple output in one cell

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

print('The notebook is set up to display multiple output in one cell.')
# Out:
# The notebook is set up to display multiple output in one cell.

# %%
# conventional way to import pandas and numpy

import pandas as pd
import numpy as np

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <center><b><font size="6">PART ONE</font></b></center></div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 1:</b>
#
# <b>Given:</b> &emsp;states_list = ['Illinois', 'Indiana', 'Iowa', 'Michigan', 'Minnesota', 'Ohio', 'Wisconsin']
# <p>&nbsp;</p>
# <b>Task:</b> &emsp;Create a Pandas Series from the list given above.  Name the Pandas Series <b>states_series</b>.

# %%
states_list = ['Illinois', 'Indiana', 'Iowa', 'Michigan', 'Minnesota', 'Ohio', 'Wisconsin']
states_series = pd.Series(states_list)
states_series
# Out:
# 0     Illinois
# 1      Indiana
# 2         Iowa
# 3     Michigan
# 4    Minnesota
# 5         Ohio
# 6    Wisconsin
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 2:</b>
#
# <b>Task:</b>&emsp;Create a custon index for the <b>states_series</b> above by passing the Series constructor function the numeric index [13, 14, 15, 22, 23, 35, 49].

# %%
states_series= pd.Series(states_list,index=[13,14,15,22,23,35,49])
print(states_series)
# Out:
# 13     Illinois
# 14      Indiana
# 15         Iowa
# 22     Michigan
# 23    Minnesota
# 35         Ohio
# 49    Wisconsin
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 3:</b>
#
# <b>Task:</b>&emsp;Create a custon index for the <b>states_series</b> above by passing the Series constructor function the string index ['IL', 'IN', 'IO', 'MI', 'MN', 'OH', 'WI'].
# </div>

# %%
states_series= pd.Series(states_list,index=['IL', 'IN', 'IO', 'MI', 'MN', 'OH', 'WI'])
print(states_series)
# Out:
# IL     Illinois
# IN      Indiana
# IO         Iowa
# MI     Michigan
# MN    Minnesota
# OH         Ohio
# WI    Wisconsin
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 4:</b>
#
# <b>Given:</b>
#
# age = [78, 70, 44, 54, 42]<br>
# presidents = ['Biden', 'Trump', 'Obama', 'Bush', 'Clinton']
# <p>&nbsp;</p>
# <b>Task:</b>&emsp;Create a Pandas Series using the age list as the data and the presidents list for the index. Name the Series age_series.

# %%
age = [78, 70, 44, 54, 42]
presidents = ['Biden', 'Trump', 'Obama', 'Bush', 'Clinton']
age_series = pd.Series(age, index=presidents)
print(age_series)
# Out:
# Biden      78
# Trump      70
# Obama      44
# Bush       54
# Clinton    42
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 5:</b>
#
# <b>Given:</b>
#
# lakes = ['Superior', 'Michigan', 'Huron', 'Erie', 'Ontario']
#
# <b>Task:</b>&emsp;Create a Pandas Series using the lakes list as the data. For the index, create a NumPy array that consists of the integers 0, 1, 2, 3, 4.  Name the Series <b>lakes_series</b>.

# %%
lakes = ['Superior', 'Michigan', 'Huron', 'Erie', 'Ontario']
lakes_series = pd.Series(lakes, np.arange(0,len(lakes)))
print(lakes_series)
# Out:
# 0    Superior
# 1    Michigan
# 2       Huron
# 3        Erie
# 4     Ontario
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 6:</b>
# <p>&nbsp;</p>
# a. Create a dictionary using the information in the image found below.  Have the keys of your dictionary be the candybar names and the values of your dictionary be the number of calories in the candy bar.  Name the dictionary <b>candybar_dict</b>.<br>
#
# ![image-2.png](attachment:image-2.png)<br>
#
# b. Create a Pandas Series using the dictionary that you created in Part (a).  Name the Series <b>candybar_series</b>.

# %%
candybar_dict = {
    '3 Musketeers': 240,
    'Snickers':250,
    'BabyRuth':280,
    'KitKat':210,
    'Twix':220,
    'Reese\'s':220
}
candybar_series = pd.Series(candybar_dict)
print(candybar_series)
# Out:
# 3 Musketeers    240
# Snickers        250
# BabyRuth        280
# KitKat          210
# Twix            220
# Reese's         220
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 7:</b>
# <p>&nbsp;</p>
# a. Create a NumPy array that consists of 8 evenly spaced numbers from 25 to 75. <br>
# <p>&nbsp;</p>
# b. Use the NumPy array from Part (a) to create a Pandas Series. Name the Series <b>numbers_series</b>.

# %%
arr = np.linspace(25,75,8,dtype=int)
numbers_series = pd.Series(arr)
numbers_series
# Out:
# 0    25
# 1    32
# 2    39
# 3    46
# 4    53
# 5    60
# 6    67
# 7    75
# dtype: int32

# %% [markdown]
# <div class="alert alert-block alert-info">
# <center><b><font size="6">PART TWO</font></b></center>
# <p>&nbsp;</p>
# <center>For Questions 8-12: Use the following dataset.</center>
#
# <b><center>[schools](https://drive.google.com/file/d/1SC-WEXCPDHofUOvkP9_2Oi3MrHQJaJa2/view?usp=share_link)</center></b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 8:</b>
# <p>&nbsp;</p>
# a. Read in the <b>schools</b> dataset as a Pandas DataFrame. Name the DataFrame that you create <b>schools</b>.<br>
# <p>&nbsp;</p>
# b. Use a for loop to iterate through the columns of the <b>schools</b> DataFrame to create a separate Pandas Series for each column in the DataFrame.

# %%
schools = pd.read_csv('schools.csv')
for col in schools:
    print(pd.Series(schools[col]))
# Out:
# 0    CO
# 1    SC
# 2    IN
# 3    NJ
# 4    CA
# 5    KY
# 6    IN
# 7    CA
# 8    TX
# 9    IN
# Name: State, dtype: object
# 0    12
# 1    11
# 2    11
# 3    12
# 4    12
# 5    12
# 6    12
# 7    12
# 8    12
# 9    11
# Name: Grade, dtype: int64
# 0    Female
# 1    Female
# 2    Female
# 3      Male
# 4      Male
# 5    Female
# 6    Female
# 7      Male
# 8    Female
# 9      Male
# Name: Gender, dtype: object
# 0    17
# 1    18
# 2    18
# 3    18
# 4    16
# 5    18
# 6    17
# 7    16
# 8    17
# 9    16
# Name: Age, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 9:</b>
# <p>&nbsp;</p>
# a. Use the Pandas read_csv() function or read_table() function to import the 'State' column of the <b>schools</b> dataset as a Pandas Series.  Name the series <b>schools_series</b>.
# <p>&nbsp;</p>
# b. Use an appropriate method or attribute to check that the result from Part (a) is a Series.

# %%
schools = pd.read_csv('schools.csv',usecols=['State']).squeeze("columns")
print(schools_series)
print(type(schools_series))
# Out:
# 0    CO
# 1    SC
# 2    IN
# 3    NJ
# 4    CA
# 5    KY
# 6    IN
# 7    CA
# 8    TX
# 9    IN
# Name: State, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 10:</b>
#
# Use the dictionary below to create a Pandas Series.  Name the Series <b>new_cases_series</b>.<br>
#
# new_cases_dict = {'Monday': 7622, 'Tuesday": 5020, 'Wednesday': 4960, 'Thursday': 4206, 'Friday': 753}

# %%
new_cases_dict = {'Monday': 7622, 'Tuesday': 5020, 'Wednesday': 4960, 'Thursday': 4206, 'Friday': 753}
new_cases_series = pd.Series(new_cases_dict)    
print(new_cases_series)
# Out:
# Monday       7622
# Tuesday      5020
# Wednesday    4960
# Thursday     4206
# Friday        753
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 11:</b>
# <p>&nbsp;</p>
# a. Find the mean of the <b>new_cases_series</b> that you created in Question 10.
# <p>&nbsp;</p>
# b. Find the median of the <b>new_cases_series</b> that you created in Question 10.
# <p>&nbsp;</p>
# c. Find the maximum value of the <b>new_cases_series</b> that you created in Question 10.
# <p>&nbsp;</p>
# d. Find the minimum value of the <b>new_cases_series</b> that you created in Question 10.
# <p>&nbsp;</p>
# e. Find the sum of the elements of the <b>new_cases_series</b> that you created in Question 10.
# <p>&nbsp;</p>
# f. Find the size of the <b>new_cases_series</b> that you created in Question 10.

# %%
print(f"Mean: {new_cases_series.mean()}")
print(f"Median: {new_cases_series.median()}")
print(f"Max: {new_cases_series.max()}")
print(f"Min: {new_cases_series.min()}")
print(f"Sum: {new_cases_series.sum()}")
print(f"Size: {new_cases_series.size}")
# Out:
# Mean: 4512.2
# Median: 4960.0
# Max: 7622
# Min: 753
# Sum: 22561
# Size: 5

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 12:</b>
#
# Convert the <b>new_cases_series</b> that you created in Question 10 into a list.

# %%
print(list(new_cases_series))
# Out:
# [7622, 5020, 4960, 4206, 753]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <center><b><font size="6">PART THREE</font></b></center>
# <p>&nbsp;</p>
# <center>For Questions 13-16: Use the following dataset.</center>
#
# <b><center>[fortune1000](https://drive.google.com/file/d/1lUyWNvgNFK4TWgpBysAc3fJQvsGAxFpl/view?usp=share_link)</center></b>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 13:</b>
# <p>&nbsp;</p>
# a. Use the Pandas read_csv() function or read_table() function to import the 'Company' column of the <b>fortune1000</b> dataset as a Pandas Series. Name the series <b>company_series</b>.
# <p>&nbsp;</p>
# b. Retrieve the 700th element in the Series <b>company_series</b>.
# <p>&nbsp;</p>
# c. Retrieve the first 9 elements of the Series <b>company_series</b>.
# <p>&nbsp;</p>
# d. Retrieve the last 8 elements of the Series <b>company_series</b>.
# <p>&nbsp;</p>
# e. Retrieve all the elements from the 507th element to the 514th element (inclusive) of the Series <b>company_series</b>.
# <p>&nbsp;</p>
# f. Retrieve the 100th, 200th, 300th, ..., 900th elements from the Series <b>company_series</b>.

# %%
company_series = pd.read_csv('fortune1000.txt',usecols=['Company']).squeeze("columns")
print(company_series[699])
print(company_series[:9])
print(company_series[-8:])
print(company_series[507:515])
arr = []
for x in range(1,10):
    print(f"{x*100}th element: {company_series[(x*100)-1]}")
# Out:
# WABCO Holdings
# 0               Walmart
# 1           Exxon Mobil
# 2    Berkshire Hathaway
# 3                 Apple
# 4    UnitedHealth Group
# 5              McKesson
# 6            CVS Health
# 7            Amazon.com
# 8                  AT&T
# Name: Company, dtype: object
# 992                    Childrens Place
# 993                      Tribune Media
# 994          Healthcare Services Group
# 995           SiteOne Landscape Supply
# 996    Charles River Laboratories Intl
# 997                          CoreLogic
# 998                       Ensign Group
# 999                                HCP
# Name: Company, dtype: object
# 507                   Williams-Sonoma
# 508    Fortune Brands Home & Security
# 509                          Big Lots
# 510         Robert Half International
# 511                     Post Holdings
# 512                            Hasbro
# 513           Hanover Insurance Group
# 514                           Navient
# Name: Company, dtype: object
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 14:</b>
# <p>&nbsp;</p>
# a. Use the Pandas read_csv() function or read_table() function to import the 'Sector' column of the <b>fortune1000</b> dataset as a Pandas Series. Name the series <b>sector_series</b>.
# <p>&nbsp;</p>
# b. Find the unique values in the Series <b>sector_series</b> that you created in Part (a).
# <p>&nbsp;</p>
# c. Find the number of unique values in the Series <b>sector_series</b> that you created in Part (a).
# <p>&nbsp;</p>
# d. Use the appropriate method to return the number of occurrences of each unique value in the Series <b>sector_series</b> that you created in Part (a).

# %%
sector_series = pd.read_csv('fortune1000.txt',usecols=['Sector']).squeeze("columns")
print(f"Unique elements: \n{sector_series.unique()}\n")
uniquearr = np.array(sector_series.unique()).tolist()
print(f"Number of unique values: {len(uniquearr)}")
arr = np.array(sector_series).tolist()
for x in uniquearr:
    print(f"Unique Element: {x} | Number of Occurrences in sector_series: {arr.count(x)}\n")
# Out:
# Unique elements:
# ['Retailing' 'Energy' 'Financials' 'Technology' 'Health Care'
#  'Wholesalers' 'Telecommunications' 'Motor Vehicles & Parts'
#  'Food &  Drug Stores' 'Industrials' 'Aerospace & Defense'
#  'Household Products' 'Transportation' 'Food, Beverages & Tobacco'
#  'Chemicals' 'Media' 'Apparel' 'Materials' 'Hotels, Restaurants & Leisure'
#  'Business Services' 'Engineering & Construction']
#
# Number of unique values: 21
# Unique Element: Retailing | Number of Occurrences in sector_series: 77
#
# Unique Element: Energy | Number of Occurrences in sector_series: 107
#
# Unique Element: Financials | Number of Occurrences in sector_series: 155
#
# Unique Element: Technology | Number of Occurrences in sector_series: 103
#
# Unique Element: Health Care | Number of Occurrences in sector_series: 71
#
# Unique Element: Wholesalers | Number of Occurrences in sector_series: 44
#
# Unique Element: Telecommunications | Number of Occurrences in sector_series: 10
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 15:</b>
# <p>&nbsp;</p>
# a. Sort the Series <b>company_series</b> in ascending order.
# <p>&nbsp;</p>
# b. Sort the Series <b>sector_series</b> in descending order.

# %%
print(f"Sorting in ascending order: \n{company_series.sort_values(ascending=True)}")
print(f"Sorting in ascending order: \n{company_series.sort_values()}")
# Out:
# Sorting in ascending order:
# 96                         3M
# 909      99 Cents Only Stores
# 403    A-Mark Precious Metals
# 836               A. Schulman
# 731                A.O. Smith
#                 ...
# 784            Zions Bancorp.
# 506                    Zoetis
# 308                      eBay
# 451               iHeartMedia
# 284            salesforce.com
# Name: Company, Length: 1000, dtype: object
# Sorting in ascending order:
# 96                         3M
# 909      99 Cents Only Stores
# 403    A-Mark Precious Metals
# 836               A. Schulman
# 731                A.O. Smith
#                 ...
# 784            Zions Bancorp.
# 506                    Zoetis
# 308                      eBay
# 451               iHeartMedia
# 284            salesforce.com
# Name: Company, Length: 1000, dtype: object

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question 16:</b>
# <p>&nbsp;</p>
# a. Count the number of missing values in the Series <b>company_series</b>.
# <p>&nbsp;</p>
# b. Count the number of missing values in the Series <b>sector_series</b>.

# %%
print(f"number of missing values in company_series: {company_series.isna().sum()}")
print(f"number of missing values in sector_series: {sector_series.isna().sum()}")
# Out:
# number of missing values in company_series: 0
# number of missing values in sector_series: 0
