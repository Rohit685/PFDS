# %% [markdown]
# # <center><b>WORKING WITH JUPYTER NOTEBOOKS -- PRESENTATION #3</b></center>

# %% [markdown]
# ![Jupyter%20Logo.JPG](attachment:Jupyter%20Logo.JPG)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">LINE BREAK</font></b>
# </div>

# %% [raw]
# LINE BREAK
# **********
#
# A line break is the termination of the previous line and the beginning of a new line.

# %% [raw]
# Markdown Syntax LINE BREAK
# **************************
#
# 1. To force a line return, place two or more empty spaces at the end of a line and press the Enter key
#
# 2. Just add <br> where you would like to make the new line.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  Add cells below to practice line breaks.
#
#  </div>

# %% [markdown]
# <a id=5></a>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">BLOCKQUOTES</font></b>
# </div>

# %% [raw]
# BLOCKQUOTES
# ***********
#
# Blockquotes can hold the large chunk of text and are generally indented.
#
# The blockquote element is used to indicate the quotation of a large section of text from another source.

# %% [raw]
# Markdown Syntax for BLOCKQUOTES
# *******************************
#
# > This is a blockquote

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  In the cell below, use the proper Markdown syntax to write the given phrase as a block quote.
#
# <p>&ensp;</p> This is an example of a block quote.
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  In the cell below, use the proper Markdown syntax to write the given quote as a block quote.
#
# <p>&ensp;</p>
#
#
# “In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since.
# "Whenever you feel like criticizing any one," he told me, "just remember that all the people in this world haven't had the advantages that you've had.”
#
# ― F. Scott Fitzgerald, The Great Gatsby

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">NESTED BLOCKQUOTES</font></b>
# </div>

# %% [raw]
# Markdown Syntax for NESTED BLOCK QUOTING
# ****************************************
#
# > some text
# >> and then some more text
# >>> and then some more

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  In the cell below, use the proper Markdown syntax to write the given text as a nested blockquote. Note: In your nested blockquote, only include the text after the dashes in each line of the given text.
#
# <p>&ensp;</p>
#
# First blockquote is -- We are learning Python.
#
# Second blockquote (indented) -- To learn Python, we need to know how to use Jupyter Notebook.
#
# Third blockquote (further indented) -- That is why we are practicing Jupyter Notebook techniques today!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">ORDERED LIST</font></b>
# </div>

# %% [raw]
# The Ordered List is a numbered list.

# %% [raw]
# Markdown Syntax
# ***************
#
# 1. Cheese
# 2. Carrot
# 3. Coconut
#
# Note: Numbering is irrelevant

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  In the cell below, create an ordered list for the terms NORTH, SOUTH, EAST, WEST.
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">UNORDERED LIST</font></b>
# </div>

# %%
UNORDERED LIST

The Unordered list is a bullet list.

# %% [raw]
# Markdown Syntax for an UNORDERED LIST
# *************************************
#
# - Cheese
# - Carrot
# - Coconut

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>
#
# In the first cell below, enter the following code just as it is and see what output you receive:
# <p>&nbsp;</p>
# Data Science<br>
# Machine Learning<br>
# Artificial Intelligence<br>
# <p>&nbsp;</p>
# In the second cell below, use Markdown syntax to created an unordered list (i.e. a bullet list) for the same three terms.
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">OUTLINE / LIST</font></b>
# </div>

# %% [raw]
# Markdown Syntax for an OUTLINE/LIST
# ***********************************
#
# 1. Main list <br>
# a. Sub-list <br>
# b. sub list
# 2. Main list
# * Next text item

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>
#
# In the cell below, run the Markdown syntax for an OUTLINE/LIST from the cell above.
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">REFERENCE STYLE FORMATTING FOR IMAGES</font></b>
# </div>

# %% [raw]
# You can also use the reference-style format for the images that you insert into Jupyter Notebook:
#
# Markdown Syntax for REFERENCE STYLE FORMATTING FOR IMAGES
# *********************************************************
#
# ![][some-id]

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>
#
# In the cells below, run the following examples which demonstrate Markdown syntax for REFERENCE STYLE FORMATTING FOR IMAGES.
# <p>&ensp;</p>
# Example 1:
# ![Here is an image for Anaconda!!]:https://blog.desdelinux.net/wp-content/uploads/2017/09/Anaconda-Navigator-Comunidad.png
# <p>&ensp;</p>
# Example 2:
# ![Python Logo]: https://www.python.org/static/community_logos/python-logo-master-v3-TM.png
#
#  </div>

# %% [markdown]
# [some-id]: https://www.python.org/static/community_logos/python-logo-master-v3-TM.png "Python Logo"

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">REFERENCE-STYLE LINKS</font></b>
# </div>

# %% [raw]
# Markdown Syntax for REFERENCE-STYLE LINKS
# *****************************************
#
# This is [a reference][id]
#
# [id]: https://en
# .wikipedia.org "Wikipedia"
#
# Note: Link IDs are not case-sensitive.
#
# -------------------------------------------------------------------------------------------------------------------------------
#
# You don’t really have to give your link an ID. If you use the words in the first set of brackets to later define the link, Markdown will understand it. This works as follows:
#
# This is [a reference][]
#
# [a reference]: https://en.wikipedia.org "Wikipedia"

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>
#
# In the cells below, run the following examples which demonstrate Markdown syntax for REFERENCE-STYLE LINKS.
# <p>&ensp;</p>
# Example 1:
# [id]: https://en.wikipedia.org "Wikipedia"
# <p>&ensp;</p>
# Example 2:
# ![Wikipedia]:https://en.wikipedia.org
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">ANCHOR LINKS</font></b>
# </div>

# %% [raw]
# ANCHOR LINKS
# ************
# An anchor link is a link on a page that brings you to a specific place on that page. In a Jupyter Notebook, it can be used to link to any section of the notebook for easy navigation.
#
# Note: The ID used for the linking should be unique to avoid misdirection.
#
# Technique 1
# ------------
#
# ● Create a new cell above the section you want to link to and add the following line of code:  <a id="id"></a>
#
# ● To create an anchor link that links to the above section, simply add the following line of code:
#
#   [Section title](#id)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  To see an example of an ANCHOR LINK using Techique 1, do the following:
# <p>&ensp;</p>
# In the cell below, run the following code:
# <p>&ensp;</p>
# ● [BLOCKQUOTES](#5)
# <p>&ensp;</p>
# In the cell above the BLOCKQUOTES cell, run the following code:
# <p>&ensp;</p>
#
# ![code.JPG](attachment:code.JPG)
#
#  </div>

# %% [raw]
# Technique 2
# -----------
#
# If you have a section with the heading — My Great Heading then to add an anchor link to this section, simply add a hyphen in place of the blank space like below:
#
# [Section title](#My-Great-Heading)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b>  To see an example of an ANCHOR LINK using Techique 2, do the following:
#
# In the cell below, run the following code:
# <p>&ensp;</p>
# ● [SECTION TO MOVE TO:](#ORDERED LIST)
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">TASK LISTS</font></b>
# </div>

# %% [markdown]
# Markdown Syntax for TASK LISTS
#
# - [x] Task 1
# - [ ] Task 2
# - [ ] Task 3

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b> In the cell below, run the appropriate code to create a TASK LIST for the following tasks:
#
# Do the laundry (done); Make dinner (not done);  Go grocery shopping (done); Do homework (not done)
#
#  </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">TABLES</font></b>
# </div>

# %% [raw]
# MAKING A TABLE IN MARKDOWN
#
# A table can be constructed using | (pipe symbol) and — (dash) to mark columns and rows.
# Markdown Syntax
#
# |Header|Header|Header|
# |------|------|------|
# |A     |B     |C     |
# |X     |Y     |Z     |
#
# Note: It is not important to add spaces after each text, roughly aligning with the columns will do just fine.
#
# Also, the number of dashes is irrelevant and is just cosmetical.
#
# The text in each header and cell of a table will by default justify to the right.
#
# For manually changing the justification, you can use:
#
# Note: Colons can be used to align columns.
#
# Use:  :--- Left align
# Use:  ---: Right align
# Use:  :---: Center align

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b> Run and study the code in the following cell to see and undertsand how to make a table in a Markdown cell.
#
#  </div>

# %% [markdown]
# | How | To | Make | a table|
# | :---: | :---: | :---: | :---: |
# | in   | <span style= 'background:yellow'> Jupyter </span>| <span style= 'background:yellow'> Notebook </span>| <span style= 'background:yellow'> Markdown </span> |
# | It | is | really| cool |

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">YOUTUBE VIDEOS
# <p>&ensp;</p>
# (EMBEDDING AN IMAGE THAT LINKS TO A YOUTUBE)</font></b>
# </div>

# %% [raw]
# Showing a YouTube Video In A Markdown Cell
#
# ******************************************
#
# Example 1
# ---------
#
# [![YouTube Video Link](http://img.youtube.com/vi/YOUR_YUOTUBE_VIDEO_ID/0.jpg)](http://www.youtube.com/watch?v=YOUR_YUOTUBE_VIDEO_ID)
#
#
# Example 2
# ---------
# [![YouTube Video Link](http://img.youtube.com/vi/jqSuaRpCnro/0.jpg)](http://www.youtube.com/watch?v=jqSuaRpCnro)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b> Run and study the code in the following cell to see and undertsand how to embed an image that links to a YouTube.
#
#  </div>

# %% [markdown]
# [![Giannis -- Ego, Pride, and Humility](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS7lPIEt1PKmdIpO7w3QuRN-PKUHQquse7iHQ&usqp=CAU)](https://www.youtube.com/watch?v=-qLchg4xkOY)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">DEFINITION LISTS</font></b>
# </div>

# %% [raw]
# DEFINITION LISTS in a Markdown Cell
# ***********************************
#
# Markdown syntax
# ---------------
#
# <dl>
# <dt>First Term</dt>
# <dd>This is the definition of the first term.</dd>
# <dt>Second Term</dt>
# <dd>This is one definition of the second term. </dd>
# <dd>This is another definition of the second term.</dd>
# </dl>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b> Run and study the code in the following cell to see and undertsand how to make a DEFINITION LIST in a Markdown cell..
#
#  </div>

# %% [markdown]
# <dl>
# <dt>Variable</dt>
# <dd>Placeholder for texts and numbers. The equal sign (=) is used to assign values to variables.
# </dd>
# <dt>Expression</dt>
# <dd>This is one definition of Expression: Python code that produces a value. </dd>
# <dd>This is another definition of Expression: Expressions are representations of value. </dd>
# </dl>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">NAVIGATION MENUS</font></b>
# </div>

# %%
NAVIGATION MENU in a Markdown Cell
**********************************

It defines a set of navigation links.

Markdown syntax
---------------

<nav>
<a href=”https://www.google.com">LinkedIn</a> |
<a href=”/css/”>Github</a> |
<a href=”/js/”>Medium</a> |
</nav>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b> Run and study the code in the following cell to see and undertsand how to make a NAVIGATION MENU in a Markdown cell..
#
#  </div>

# %% [markdown]
# <nav>
# <a href=”https://www.google.com">LinkedIn</a> |
# <a href=”/css/”>Github</a> |
# <a href=”/js/”>Medium</a> |
# </nav>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">LaTeX MATH</font></b>
# </div>

# %% [markdown]
# ### LaTeX is a system for high-quality technical typesetting. Most mathematicians and many other people use LaTeX to typeset papers, exams, books, and more. The LaTeX Project Home Page has additional information.
#
# ### Jupyter Notebooks’ Markdown cells support LateX for formatting mathematical equations.

# %% [markdown]
# To tell Markdown to interpret your text as LaTex, surround your input with dollar signs like this: (RUN THIS CELL IN MARKDOWN!)
#
# $\sqrt{k}$

# %% [markdown]
# ### We will not focus on learning LaTex at this time, but if the need arises, we will address it.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">GEOMETRIC SHAPES</font></b>
# </div>

# %% [raw]
# GEOMETRIC SHAPES in Markdown Cells
# *********************************
#
# Use &# followed by the decimal or hex reference number followed by a semicolon ; for the geometric shapes rendering.
#
# Syntax:
# ------
#
# &#HexaCode;

# %% [markdown]
# [Decimal and Hex Reference Numbers](https://www.w3schools.com/charsets/ref_utf_geometric.asp)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b><font size="6">TABLE OF CONTENTS</font></b>
# </div>

# %% [markdown]
# [Table of Contents in Jupyter Notebook](https://moonbooks.org/Articles/How-to-create-a-table-of-contents-in-a-jupyter-notebook-/)

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Example:</b> Run and study the code in the following cell to see and undertsand how to make GEOMETRIC FIGURES in a Markdown cell..
#
#  </div>

# %% [markdown]
# &#9635;
# &#9710;
# &#9699;

# %% [markdown]
# ![green%20light.JPG](attachment:green%20light.JPG)

# %% [markdown]
# # <center><b>WORKING WITH JUPYTER NOTEBOOKS -- PRESENTATION #4</b></center>
# # <center><b>SOME ADDITIONAL INFORMATION</b></center>
# # <center><b>WORKING WITH JUPYTER NOTEBOOK</b></center>

# %% [markdown]
# ![Jupyter%20Logo.JPG](attachment:Jupyter%20Logo.JPG)

# %% [markdown]
# # The information below comes from the following source:
#
# [Earth Lab -- Earth Data Analytics Online Certificate](http://localhost:8889/notebooks/PFDS/02%20Jupyter%20Notebook/03%20Jupyter%20Notebook%20In-Class%20Presentation%20%234.ipynb#6)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><font size="6">CLEARING OUTPUT IN JUPYTER NOTEBOOK</font></b>
# </div>

# %% [markdown]
# ![Clear%20Results.JPG](attachment:Clear%20Results.JPG)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><font size="6">MANAGING DIRECTORIES IN JUPYTER NOTEBOOK</font></b>
# </div>

# %% [markdown]
# ![Dir%201.JPG](attachment:Dir%201.JPG)

# %% [markdown]
# ![Dir%202.JPG](attachment:Dir%202.JPG)

# %% [markdown]
# ![Dir%203.JPG](attachment:Dir%203.JPG)

# %% [markdown]
# ![Dir%204.JPG](attachment:Dir%204.JPG)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b><font size="6">MANAGING JUPYTER NOTEBOOK FILES</font></b>
# </div>

# %% [markdown]
# ![Dir%205.JPG](attachment:Dir%205.JPG)

# %% [markdown]
# ![Dir%206.JPG](attachment:Dir%206.JPG)

# %% [markdown]
# ![Dir%207.JPG](attachment:Dir%207.JPG)

# %% [markdown]
# ![Dir%208.JPG](attachment:Dir%208.JPG)

# %% [markdown]
# ![Dir%209.JPG](attachment:Dir%209.JPG)

# %% [markdown]
# ![Dir%2011.JPG](attachment:Dir%2011.JPG)

# %% [markdown]
# ![files1.JPG](attachment:files1.JPG)

# %% [markdown]
# ![files2.JPG](attachment:files2.JPG)

# %% [markdown]
# ![files3.JPG](attachment:files3.JPG)

# %% [markdown]
# ![files4.JPG](attachment:files4.JPG)

# %% [markdown]
# ![files5.JPG](attachment:files5.JPG)

# %% [markdown]
# ![files6.JPG](attachment:files6.JPG)

# %% [markdown]
# <div class="alert alert-block alert-danger"><font size="7">
# <b><center><b>
# ONE LAST IMPORTANT THOUGHT
#     </b></center></b></font>
# </div>

# %% [markdown]
# [Apple's Simple Marketing Manifesto](https://www.entrepreneur.com/article/220603)
