# %% [markdown]
# # <center><b>JUPYTER NOTEBOOK ASG 2.3</b></center>

# %% [markdown]
# <div id="Question1"class="alert alert-block alert-success"><b>Question #1:</b>
# Run the following code in two different Jupyter notebook cells. Run one cell as a code cell. Run the other cell as a Markdown cell. Why is the output different? Provide your explanation in the third cell.
# <p>&nbsp;</p>
# # This class is called Python for Data Science.
# </div>

# %%
# This class is called Python for Data Science.

# %% [markdown]
# # This class is called Python for Data Science.

# %% [markdown]
# The code cell does not run because # is the keyword for commenting in python. The # for the markdown cell makes the sentence a header.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #2:</b>:
# Recreate the following table in one Jupyter notebook markdown cell:
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #2:</b>:
# Recreate the following table in one Jupyter notebook markdown cell:
#
# ![Table%20Asg%203-2.png](attachment:Table%20Asg%203-2.png)
#
# Note:  Use Markdown formatting. Do not just insert a copy of an image of the table.
#
# </div>

# %% [markdown]
# | Python Package|    <center>Use</center>         |
# | :-----      | :---------  |
# | NumPy       | Numerican Computing       |
# | pandas   | data analysis        |
# | matplotlib | data visualization|
# | scikit-learn | machine learning|
# | SciPy | scientific computing|
# | statsmodel | scientific computing|
# | seaborn | data visualization|

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #3:</b>: Recreate the following list as a bullet point list (i.e. as an unordered list) in one Jupyter notebook markdown cell:
#
# markdown cell : markdown<br>
# code cell: Python code<br>
# raw NBConvert: LaTeX
# </div>

# %% [markdown]
# - markdown cell
#     - markdown
# - code cell
#     - Python code
# - raw NBConvert
#     - LaTeX

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #4:</b>:
# Recreate the following items as an ordered list in one Jupyter notebook markdown cell:
#
# Open Jupyter notebook<br>
# Write code<br>
# Restart Kernel & run all<br>
# Download notebook
#
# </div>

# %% [markdown]
# 1. Open Jupyter notebook
# 1. Write code
# 1. Restart Kernel & run all
# 1. Download notebook

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #5:</b>: In the cell below, insert an image of a logo for the Python pandas library.
#
# </div>

# %% [markdown]
# <img src="..\Images/pandas.png">

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #6:</b>:
# Use Markdown formatting to recreate the following outline in one Jupyter notebook markdown cell:
#
# Python for Data Science<br>
# a. Attendance Questions(s)<br>
# b. Presentation<br>
# c. Coding Activity<br>
# Honors Precalculus<br>
# a. Test<br>
# b. New Material<br>
# <p>&nbsp;</p>
# Reminder: Make copies!!
#
# </div>

# %% [markdown]
# Python for Data Science</br>
# a. Attendance Question(s)</br>
# b. Presentation</br>
# c. Coding Activity</br>
# Honors Precalculus</br>
# a. Test</br>
# b. New Material</br>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #7:</b>: In the cell below, recreate the given passage by making the following revisions:
#
# 1. Add a heading that says -- Words of Wisdom from Giannis (use the largest heading size)
# 2. Change the font to Verdana and the font size to 5.
# 3. Use bold font for the words -- ego, pride, humility, and humble
# 4. Use italics for the words/phrases -- past, future, on the moment
#
# The mindset to have? When you focus on the past, that's your ego. 'I did this in the past. I won that in the past.'
#
# When I focus on the future, that's my pride. 'I'm going to dominate.' That's your pride talking.
#
# I try to focus on the moment. In the present. That's humility. That's being humble. That's a skill I'm trying to master. And it's been working so far. So I'm not going to stop.
# </div>

# %% [markdown]
# # Words of Wisdom from Giannis
#
# The mindset to have? When you focus on the *past*, that's your **ego**. 'I did this in the past. I won that in the past.'
#
# When I focus on the *future*, that's my **pride**. 'I'm going to dominate.' That's your pride talking.
#
# I try to focus on the *moment*. In the present. That's **humility**. That's being **humble**. That's a skill I'm trying to master. And it's been working so far. So I'm not going to stop.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #8:</b>: In the cell below, make nested blockquotes for the following passage. Use 3 levels in your nested blockquotes.
#
# The mindset to have? When you focus on the past, that's your ego. 'I did this in the past. I won that in the past.'
#
# When I focus on the future, that's my pride. 'I'm going to dominate.' That's your pride talking.
#
# I try to focus on the moment. In the present. That's humility. That's being humble. That's a skill I'm trying to master. And it's been working so far. So I'm not going to stop.
# </div>
# </div>

# %% [markdown]
# > The mindset to have? When you focus on the past, that's your ego. 'I did this in the past. I won that in the past.'
#
# >> When I focus on the future, that's my pride. 'I'm going to dominate.' That's your pride talking.
#
# >>> I try to focus on the moment. In the present. That's humility. That's being humble. That's a skill I'm trying to master. And it's been working so far. So I'm not going to stop.

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #9:</b>: In the cells below, do the following:<br>
#
# First Cell: Use a red background with the phrase -- Danger: If I don't study, I won't do well in school.<br>
# Make the font blue and put the word Danger: in bold italics.
#
# Second Cell: Put in a heading that says -- "Highlighting Markdown Text" (without the quotes) and then beneath that heading enter the phrase -- "The Python logo uses the colors blue and yellow." Make the text color blue and highlight the phrase in yellow. Also inset an image of a Python logo in this cell.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <p style="color:blue"> <b><i>Danger</i></b>: If I don't study, I won't do well in school</p>
# </div>

# %% [markdown]
# ## Highlighting Markdown Text
#
# <p style="color:blue;background-color:yellow;">The Python logo uses the colors blue and yellow.</p>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Question #10:</b>: In the cell below, create a DEFINITION LIST for the following terms:<br>
#
# Algorithm<br>
# Debugging<br>
# Exception
#
# </div>

# %% [markdown]
#  <dl break=all>
#         <dt>Algorithm
#         <dd>Specific sequence in order to accomplish a specific task
#         <dt>Debugging
#         <dd>The process of finding and fixing errors in your code.
#         <dt>Exception
#         <dd>Event in the program that was unplanned such as invalid input or syntax errors
#       </dl>

# %% [markdown]
# <div class="alert alert-block alert-success"><b>Extra Credit:</b>: In the cell below, create an ANCHOR LINK that will take us back to the beginning of the assignment (i.e. back to Question #1)<br>In the cell two cells below this cell, provide an explanation of how you created the ANCHOR LINK.
#
# </div>

# %% [markdown]
# [jump to code cell 1](#Question1)

# %% [markdown]
# In order to create an anchor link, I had to add an id to the div in question 1. I added an id of 'Question1'. Than in order to link to that id, I used the mardown syntax of `[jump to code cell 1](#Question1)`.
